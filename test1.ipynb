# %%
print("Hello world")
# Out:
# Hello world

# %%
data= [10, 50, 50, 30, 50]
max_val= max(data)
#print(max_val)
all_max= [i for i, v in enumerate(data) if v==max_val]
print(all_max)
# Out:
# [1, 2, 4]

# %%
data= {"a":1, "b": 2}
print(list(data.keys()))
# Out:
# ['a', 'b']
